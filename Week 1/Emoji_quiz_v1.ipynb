# %%
import time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image

# %matplotlib inline

url1='https://raw.githubusercontent.com/nikki099/CA_WK1/main/emoji_awesome.gif'#awesome gif
url2='https://raw.githubusercontent.com/nikki099/CA_WK1/main/emoji_not_bad.gif'#not bad gif
url3='https://raw.githubusercontent.com/nikki099/CA_WK1/main/emoji_notgood.gif'#not good gif


#greeting and obtain the users' name
print("Hello there! What's your name?\n")
time.sleep(1)

#user input
name=input("Enter your name to the blank: \n")
time.sleep(1)
print()
print(f"Nice to meet you, {name}!")

#user to confirm to start the quiz
print("Let's start the fun Emoji Quiz, are you ready?")
print("Enter 'yes' to start the quiz!")
answer=str(input("")).lower().strip()
    
while answer!="yes":
    print("Enter 'yes' to start the quiz!")
    answer=str(input("")).lower().strip()
    #answer=answer.lower().strip()
    
if answer=="yes":
    win=0
    total_correct_answers=5
    print("GAME ON!")


    #quiz1_sunglasses
    print("\nQuiz 1")
    img = mpimg.imread('https://raw.githubusercontent.com/nikki099/PythonCourse_Assignment1/8e8e16fd5832e79145653b3908a2be31a24d0b25/emoji%20sunglasses.PNG')
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()


    print("Enter your guess below:\n" 
          "**hint: 1 word, the answer is not case sensitive.**")
    answer1=input("")
    answer1=str(answer1).lower().strip()

    if answer1=="sunglasses"or answer1=="sunnies":
        print("Correct!")
        win+=1
    else:
        print("Incorrect! It's SUNGLASSES or SUNNIES")

    print("\nloading next question...")
    time.sleep(2)



    #Quiz2_bad_luck
    print("\nQuiz 2")    
    img = mpimg.imread('https://raw.githubusercontent.com/nikki099/PythonCourse_Assignment1/8e8e16fd5832e79145653b3908a2be31a24d0b25/emoji_badluck.PNG')
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()


    print("Enter your guess below:\n" 
          "**hint: 2 words**")
    answer2=input("")
    answer2=str(answer2).lower().strip()

    if answer2=="bad luck":
        print("Correct!")
        win+=1
    else:
        print("Incorrect! It's BAD LUCK.")
    print("loading next question...")    
    time.sleep(2)


    #Quiz3_kitkat
    print("\nQuiz 3")    
    img = mpimg.imread('https://raw.githubusercontent.com/nikki099/PythonCourse_Assignment1/main/emoji_kitkat.PNG')
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()


    print("Enter your guess below:\n" 
          "**hint: 1 word**")
    answer3=input("")
    answer3=str(answer3).lower().strip()

    if answer3=="kitkat":
        print("Correct!")
        win+=1
    else:
        print("Incorrect! It's KITKAT.")
    print("\nloading next question...")    
    time.sleep(2)

    #Quiz4_red_bull
    print("\nQuiz 4")    
    img = mpimg.imread('https://raw.githubusercontent.com/nikki099/PythonCourse_Assignment1/main/emoji_red_bull.PNG')
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()


    print("Enter your guess below:\n" 
          "**hint: 2 words**")
    answer4=input("")
    answer4=str(answer4).lower().strip()

    if answer4=="red bull":
        print("Correct!")
        win+=1
    else:
        print("Incorrect! It's RED BULL.")
    print("loading next question...")    
    time.sleep(2)


    #Quiz5_burger_king
    print("\nQuiz 5")    
    img = mpimg.imread('https://raw.githubusercontent.com/nikki099/PythonCourse_Assignment1/main/emoji_burger_king.PNG')
    imgplot = plt.imshow(img)
    plt.axis('off')
    plt.show()


    print("Enter your guess below:\n" 
          "**hint: 2 words**")
    answer5=input("")
    answer5=str(answer5).lower().strip()

    if answer5=="burger king":
        print("Correct!")
        win+=1
        print("Game Over! Please wait for your score.") 
    else:
        print("Incorrect! It's BURGER KING.")
        print("Game Over! Please wait for your score.") 
    time.sleep(1)
    print("...")
    time.sleep(1)
    print("...")
    time.sleep(1)
    print("...")

    print(f"{name}, your final socre is:{win} out of 5!")

    
    if win==5:
        print("You are an Emoji Whizard!")
        img=Image(url1, width=375, height=200)

    elif win>=3 and win<5:
        print("Not bad, keep up the good work!")
        img=Image(url2,width=375, height=200) 
    else:
        print("Well, practice makes perfect. Keep playing!")
        img=Image(url3,width=375, height=200)

    display(img)
# Out:
# Hello there! What's your name?
#
# Enter your name to the blank:
#
#
# Nice to meet you, !
# Let's start the fun Emoji Quiz, are you ready?
# Enter 'yes' to start the quiz!
# yes
# GAME ON!
#
# Quiz 1
# Enter your guess below:
# **hint: 1 word, the answer is not case sensitive.**
# sunnies
# Correct!
#
# loading next question...
#
# Quiz 2
# Enter your guess below:
# **hint: 2 words**
# bed luck
# Incorrect! It's BAD LUCK.
# loading next question...
#
# Quiz 3
# Enter your guess below:
# **hint: 1 word**
# kitkat
# Correct!
#
# loading next question...
#
# Quiz 4
# Enter your guess below:
# **hint: 2 words**
# red bull
# Correct!
# loading next question...
#
# Quiz 5
# Enter your guess below:
# **hint: 2 words**
# burger king
# Correct!
# Game Over! Please wait for your score.
# ...
# ...
# ...
# , your final socre is:4 out of 5!
# Not bad, keep up the good work!
